# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from SVM import SVM

# %%
N = 500
X_1_pos = np.random.rand(N) * 4 * np.pi
X_2_pos = np.sin(X_1_pos) + np.random.normal(0, 0.4, N)
X_pos = np.array([[x_1, x_2, 1] for x_1, x_2 in zip(X_1_pos, X_2_pos)])
plt.scatter(X_1_pos, X_2_pos, c='b')
X_1_neg = np.random.rand(N) * 4 * np.pi
X_2_neg = np.sin(X_1_neg) + np.random.normal(0, 0.4, N) - 1
X_neg = np.array([[x_1, x_2, -1] for x_1, x_2 in zip(X_1_neg, X_2_neg)])
plt.scatter(X_1_neg, X_2_neg, c='r')
plt.show()
X = np.vstack([X_pos, X_neg])
np.random.shuffle(X)
y = X[:, 2]
X = X[:, :2]

# %%
model = SVM()

# %%
model.fit(X, y)

# %%
model.elapsed_time
# Out:
# 0.8057489395141602

# %%
y_pred = model.predict(X)

# %%
model.score(y, y_pred)
# Out:
# 0.758

# %%
model2 = SVM(kernel='sigmoid')

# %%
model2.fit(X, y)

# %%
y_pred = model2.predict(X)
model2.score(y, y_pred)
# Out:
# 0.759

# %%
model2.elapsed_time
# Out:
# 0.733651876449585

# %%
model3 = SVM(kernel='linear')

# %%
model3.fit(X,y)

# %%
y_pred = model3.predict(X)
model3.score(y, y_pred)
# Out:
# 0.762

# %%
model3.elapsed_time
# Out:
# 0.990875244140625

# %%
import train

# %%
train.main()
# Out:
# 線形データ
# 正解率: 0.986
# 学習時間： 0.185
# RBF
# データ数： 50
# 正解率: 0.830
# 学習時間： 0.071
# データ数： 100
# 正解率: 0.745
# 学習時間： 0.145
# データ数： 500
# 正解率: 0.757
# 学習時間： 1.347
# データ数： 1000
# 正解率: 0.787
# 学習時間： 2.750
# Sigmoid
# データ数： 50
# 正解率: 0.720
# 学習時間： 0.036
# データ数： 100
# 正解率: 0.760
# 学習時間： 0.108
# データ数： 500
# 正解率: 0.768
# 学習時間： 0.954
# データ数： 1000
# 正解率: 0.765
# 学習時間： 3.283
# Linear
# データ数： 50
# 正解率: 0.800
# 学習時間： 0.053
# データ数： 100
# 正解率: 0.810
# 学習時間： 0.151
# データ数： 500
# 正解率: 0.743
# 学習時間： 1.342
# データ数： 1000
# 正解率: 0.751
# 学習時間： 3.800
#         RBF Sigmoid  Linear
# 50     0.83    0.72     0.8
# 100   0.745    0.76    0.81
# 500   0.757   0.768   0.743
# 1000  0.787   0.765  0.7515
#             RBF   Sigmoid    Linear
# 50    0.0709481  0.035671  0.053431
# 100    0.145169  0.107927  0.151017
# 500     1.34684    0.9541   1.34237
# 1000    2.75033   3.28256   3.79962

# %%
X, y = train.linear_data(500)

# %%
plt.scatter(X[y==1][:, 0], X[y==1][:, 1], c='b')
plt.scatter(X[y==-1][:, 0], X[y==-1][:, 1], c='r')
plt.plot(X_lin, y_lin)
plt.show()

# %%
X_lin = np.linspace(-3, 3)
y_lin = -(rbf_model.w[0] * X_lin + rbf_model.b) / rbf_model.w[1]

# %%
import pandas as pd

# %%
kernels = ['RBF', 'Sigmoid', 'Linear']

# %%
df = pd.DataFrame(index=[50, 100, 500, 1000, 5000, 10000], columns=kernels)

# %%
df.loc[50, 'RBF'] = 1

# %%
print(df)
# Out:
#        RBF Sigmoid Linear
# 50     NaN     NaN    NaN
# 100    NaN     NaN    NaN
# 500    NaN     NaN    NaN
# 1000   NaN     NaN    NaN
# 5000   NaN     NaN    NaN
# 10000  NaN     NaN    NaN

# %%
from SVM import SVM
rbf_model = SVM()
rbf_model.fit(X, y)
